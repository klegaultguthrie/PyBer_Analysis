# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "city_data.csv"
ride_data_to_load = "ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city              date   fare        ride_id  driver_count  \
# 0  Lake Jonathanshire  2019-01-14 10:14  13.83  5739410000000             5
# 1  South Michelleport  2019-03-04 18:24  30.24  2343910000000            72
# 2  Port Samanthamouth   2019-02-24 4:29  33.44  2005070000000            57
# 3          Rodneyfort  2019-02-10 23:22  23.44  5149250000000            34
# 4          South Jack   2019-03-06 4:28  34.58  3908450000000            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
ridecount_by_type=pyber_data_df.groupby(["type"]).count()["ride_id"]
ridecount_by_type
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
drivercount_by_type=city_data_df.groupby(["type"]).sum()["driver_count"]
drivercount_by_type
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
faretotal_by_type=pyber_data_df.groupby(["type"]).sum()["fare"]
faretotal_by_type
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
avgfare_per_ride=faretotal_by_type/ridecount_by_type
avgfare_per_ride
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
avgfare_per_driver=faretotal_by_type/drivercount_by_type
avgfare_per_driver
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary_df = pd.DataFrame()
pyber_summary_df["Total Rides"] = ridecount_by_type.astype('float')
pyber_summary_df["Total Drivers"] = drivercount_by_type.astype('float')
pyber_summary_df["Total Fares"] = faretotal_by_type.astype('float')
pyber_summary_df["Average Fare per Ride"] = avgfare_per_ride.astype('float')
pyber_summary_df["Average Fare per Driver"] = avgfare_per_driver.astype('float')

pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural           125.0           78.0      4327.93              34.623440
# Suburban        625.0          490.0     19356.33              30.970128
# Urban          1625.0         2405.0     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
pyber_summary_df.dtypes
# Out:
# Total Rides                float64
# Total Drivers              float64
# Total Fares                float64
# Average Fare per Ride      float64
# Average Fare per Driver    float64
# dtype: object

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural           125.0           78.0      4327.93              34.623440
# Suburban        625.0          490.0     19356.33              30.970128
# Urban          1625.0         2405.0     39854.38              24.525772
#
#           Average Fare per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
pyber_summary_df["Total Fares"]=pyber_summary_df["Total Fares"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Ride"]=pyber_summary_df["Average Fare per Ride"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Driver"]=pyber_summary_df["Average Fare per Driver"].map("${:,.2f}".format)
pyber_summary_df
# Out:
#           Total Rides  Total Drivers Total Fares Average Fare per Ride  \
# Rural           125.0           78.0   $4,327.93                $34.62
# Suburban        625.0          490.0  $19,356.33                $30.97
# Urban          1625.0         2405.0  $39,854.38                $24.53
#
#          Average Fare per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame

pyber_data_df2 = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df2.head()
# Out:
#                  city              date   fare        ride_id  driver_count  \
# 0  Lake Jonathanshire  2019-01-14 10:14  13.83  5739410000000             5
# 1  South Michelleport  2019-03-04 18:24  30.24  2343910000000            72
# 2  Port Samanthamouth   2019-02-24 4:29  33.44  2005070000000            57
# 3          Rodneyfort  2019-02-10 23:22  23.44  5149250000000            34
# 4          South Jack   2019-03-06 4:28  34.58  3908450000000            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
pyber_data_df2=pyber_data_df2.groupby(["type", "date"]).sum()[["fare"]]
pyber_data_df2
# Out:
#                          fare
# type  date
# Rural 2019-01-01 9:45   43.69
#       2019-01-02 11:18  52.12
#       2019-01-03 19:51  19.90
#       2019-01-04 3:31   24.88
#       2019-01-06 7:38   47.33
# ...                       ...
# Urban 2019-05-08 1:54   32.69
#       2019-05-08 2:31   41.33
#       2019-05-08 4:20   21.99
#       2019-05-08 4:39   18.45
#       2019-05-08 7:29   18.55
#
# [2364 rows x 1 columns]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
pyber_data_df2=pyber_data_df2.reset_index()
pyber_data_df2
# Out:
#        type              date   fare
# 0     Rural   2019-01-01 9:45  43.69
# 1     Rural  2019-01-02 11:18  52.12
# 2     Rural  2019-01-03 19:51  19.90
# 3     Rural   2019-01-04 3:31  24.88
# 4     Rural   2019-01-06 7:38  47.33
# ...     ...               ...    ...
# 2359  Urban   2019-05-08 1:54  32.69
# 2360  Urban   2019-05-08 2:31  41.33
# 2361  Urban   2019-05-08 4:20  21.99
# 2362  Urban   2019-05-08 4:39  18.45
# 2363  Urban   2019-05-08 7:29  18.55
#
# [2364 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
pivot= pyber_data_df2.pivot_table(index='date', columns="type", values="fare")
pivot
# Out:
# type              Rural  Suburban  Urban
# date
# 2019-01-01 0:08     NaN       NaN  37.91
# 2019-01-01 0:46     NaN     47.74    NaN
# 2019-01-01 12:32    NaN     25.56    NaN
# 2019-01-01 14:40    NaN       NaN   5.42
# 2019-01-01 14:42    NaN       NaN  12.31
# ...                 ...       ...    ...
# 2019-05-08 1:54     NaN       NaN  32.69
# 2019-05-08 2:31     NaN       NaN  41.33
# 2019-05-08 4:20     NaN       NaN  21.99
# 2019-05-08 4:39     NaN       NaN  18.45
# 2019-05-08 7:29     NaN       NaN  18.55
#
# [2361 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
faresbycity_date=pivot.loc['2019-01-01':'2019-04-29']
faresbycity_date.head()
# Out:
# type              Rural  Suburban  Urban
# date
# 2019-01-01 0:08     NaN       NaN  37.91
# 2019-01-01 0:46     NaN     47.74    NaN
# 2019-01-01 12:32    NaN     25.56    NaN
# 2019-01-01 14:40    NaN       NaN   5.42
# 2019-01-01 14:42    NaN       NaN  12.31

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
faresbycity_date.index = pd.to_datetime(faresbycity_date.index)
faresbycity_date
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:00    NaN       NaN  37.91
# 2019-01-01 00:46:00    NaN     47.74    NaN
# 2019-01-01 12:32:00    NaN     25.56    NaN
# 2019-01-01 14:40:00    NaN       NaN   5.42
# 2019-01-01 14:42:00    NaN       NaN  12.31
# ...                    ...       ...    ...
# 2019-04-28 04:34:00    NaN       NaN  40.46
# 2019-04-28 08:15:00    NaN       NaN  22.86
# 2019-04-28 09:03:00    NaN       NaN  15.00
# 2019-04-28 09:10:00    NaN       NaN   5.73
# 2019-04-28 09:25:00    NaN       NaN  37.35
#
# [2182 rows x 3 columns]

# %%
# 7. Check that the datatype for the index is datetime using df.info()
faresbycity_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2182 entries, 2019-01-01 00:08:00 to 2019-04-28 09:25:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     114 non-null    float64
#  1   Suburban  570 non-null    float64
#  2   Urban     1501 non-null   float64
# dtypes: float64(3)
# memory usage: 68.2 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
faresbycity_datebyweek=faresbycity_date.resample("W").sum()
faresbycity_datebyweek
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
import matplotlib.pyplot as plt

ax=faresbycity_datebyweek.plot()
ax.set_title("Total Fare by City Type")
ax.set_ylabel("Fares(USD)")
ax.set_xlabel("")
style.use('fivethirtyeight')
plt.savefig("analysis/Fig10.png")
plt.show()
